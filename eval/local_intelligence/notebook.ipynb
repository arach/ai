# %% [markdown]
# # Local Intelligence Eval on Hugging Face
#
# Notebook-friendly entrypoint for the 24-card Talkie local-intelligence bakeoff.

# %%
# !pip install -q transformers accelerate torch sentencepiece

# %%
from pathlib import Path
import json
root = Path('.')
results_dir = root / 'eval' / 'local_intelligence' / 'results'
results_dir.mkdir(parents=True, exist_ok=True)

# %%
# !python3 eval/local_intelligence/run_hf_transformers.py --model google/gemma-4-E4B-it --limit 24 --verbose

# %%
latest = sorted(results_dir.glob('*.json'))[-1]
payload = json.loads(latest.read_text())
payload['summary']

# %%
# !python3 eval/local_intelligence/run_hf_matrix.py --limit 24 --keep-going
